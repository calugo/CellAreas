# %%
import matplotlib.pyplot as plt
import pandas as pd
import glob
# %matplotlib inline

# %%
DFn=[]
Areas=[]
files=glob.glob("*csv")
print(files)
# Out:
# ['CH2.csv', 'CH3.csv', 'CH1.csv', 'CH5.csv', 'CH4.csv', 'CH6.csv', 'ch12.csv']

# %%
DFn=[pd.read_csv(k) for k in files]

# %%
DFn[0].head()
# Out:
#       Label     Area    Min     Max      BX   BY   Width  Height  Circ.  \
# 0  1  CHOP2   73.143  8.333  10.667   0.000  0.0  11.538  12.821  0.219
# 1  2  CHOP2   95.743  7.667  10.667  18.590  0.0  11.538  14.103  0.556
# 2  3  CHOP2   71.088  8.000  10.667  33.333  0.0   8.974  13.462  0.486
# 3  4  CHOP2   25.888  7.667  10.667  46.795  0.0  12.821   3.205  0.364
# 4  5  CHOP2  126.972  6.000  10.667  64.744  0.0  15.385  16.026  0.540
#
#       AR  Round  Solidity
# 0  1.307  0.765     0.672
# 1  1.934  0.517     0.837
# 2  1.996  0.501     0.771
# 3  4.726  0.212     0.792
# 4  2.328  0.430     0.862

# %% [markdown]
# ![alt text](CHOP2.gif) ![alt text](CHOP2-1.png)

# %%
ch2=set([12,18,19,14,10,15,16,21,29,31,45,57,55,56,65,59,60,79,91,87])
#print(DFn[1][' '])
for k in list(ch2):
    #print(k)
    #print(DFn[0].loc[DFn[0][' '] == k].Area.values[0])
    Areas.append(DFn[0].loc[DFn[0][' '] == k].Area.values[0])

# %%
DFn[1].head()
# Out:
#       Label    Area     Min   Max      BX   BY  Width  Height  Circ.     AR  \
# 0  1  CHOP3  20.546  10.667  13.0   0.000  0.0  4.487   7.051  0.524  1.719
# 1  2  CHOP3  55.062  10.667  13.0   9.615  0.0  8.333  12.821  0.239  2.384
# 2  3  CHOP3  66.568  10.000  13.0  23.077  0.0  7.692  14.103  0.513  2.532
# 3  4  CHOP3  32.051  11.000  13.0  33.974  0.0  7.051   7.051  0.708  1.553
# 4  5  CHOP3  39.448  11.000  13.0  62.179  0.0  9.615   8.333  0.507  1.955
#
#    Round  Solidity
# 0  0.582     0.746
# 1  0.420     0.649
# 2  0.395     0.833
# 3  0.644     0.867
# 4  0.511     0.719

# %% [markdown]
# ![alt text](CHOP3.gif) ![alt text](CHOP3-1.png)

# %%
ch3=set([22,21,26,20,16,24,18,14,31,30,28,32,33,39,40,50,57,67,88,99,98,96,94,89,101,73,74,65,59,53,89])
#print(DFn[1][' '])
for k in list(ch3):
    #print(k)
    #print(DFn[0].loc[DFn[0][' '] == k].Area.values[0])
    Areas.append(DFn[1].loc[DFn[1][' '] == k].Area.values[0])

# %%
DFn[2].head()
# Out:
#       Label     Area     Min     Max      BX   BY   Width  Height  Circ.  \
# 0  1  CHOP1   94.099  11.316  12.950   1.923  0.0  12.179   9.615  0.805
# 1  2  CHOP1  348.044   9.907  12.965  21.154  0.0  14.103  35.256  0.417
# 2  3  CHOP1   96.154   8.980  12.892  49.359  0.0  11.538  10.897  0.832
# 3  4  CHOP1    2.465  12.284  12.868  68.590  0.0   2.564   1.282  0.916
# 4  5  CHOP1   26.298  10.313  12.902  76.923  0.0   8.974   5.128  0.671
#
#       AR  Round  Solidity
# 0  1.298  0.770     0.939
# 1  3.173  0.315     0.835
# 2  1.391  0.719     0.944
# 3  1.809  0.553     0.857
# 4  1.538  0.650     0.877

# %% [markdown]
# ![alt text](CHOP1.gif) ![alt text](CHOP1-1.png)

# %%
ch1=set([11,13,16,24,22,26,32,17,55,52,58,61,33,31])

#print(DFn[1][' '])
for k in list(ch1):
    #print(k)
    #print(DFn[0].loc[DFn[0][' '] == k].Area.values[0])
    Areas.append(DFn[2].loc[DFn[2][' '] == k].Area.values[0])

# %%
DFn[3].head()
# Out:
#       Label     Area     Min  Max      BX   BY   Width  Height  Circ.     AR  \
# 0  1  CHOP5  169.707   9.000   14   0.000  0.0  10.897  31.410  0.267  2.908
# 1  2  CHOP5   99.441   9.667   14  12.821  0.0  10.256  16.026  0.385  1.894
# 2  3  CHOP5   47.666  10.333   14  25.641  0.0  12.179   5.128  0.647  2.222
# 3  4  CHOP5   24.244  11.000   14  56.410  0.0  10.256   3.846  0.519  2.249
# 4  5  CHOP5   52.186   9.667   14  69.231  0.0  10.256   7.051  0.691  1.555
#
#    Round  Solidity
# 0  0.344     0.689
# 1  0.528     0.757
# 2  0.450     0.899
# 3  0.445     0.825
# 4  0.643     0.888

# %% [markdown]
# ![alt text](CHOP5.gif) ![alt text](CHOP5-1.png)

# %%
ch5=set([17,19,27,31,28,33,40,44,23,41,39,35,23])
#print(DFn[1][' '])
for k in list(ch5):
    #print(k)
    #print(DFn[0].loc[DFn[0][' '] == k].Area.values[0])
    Areas.append(DFn[3].loc[DFn[3][' '] == k].Area.values[0])

# %%
DFn[4].head()
# Out:
#       Label     Area    Min     Max      BX   BY   Width  Height  Circ.  \
# 0  1  CHOP4  385.437  0.000  11.667   0.000  0.0  16.026  39.744  0.240
# 1  2  CHOP4  213.264  8.667  11.667  16.667  0.0  14.103  19.231  0.656
# 2  3  CHOP4   67.390  8.000  11.667  34.615  0.0   9.615   9.615  0.731
# 3  4  CHOP4   80.950  7.333  11.667  50.641  0.0  10.256  10.256  0.729
# 4  5  CHOP4   74.786  9.000  11.667  64.103  0.0  12.821   9.615  0.493
#
#       AR  Round  Solidity
# 0  3.244  0.308     0.737
# 1  1.517  0.659     0.903
# 2  1.193  0.838     0.882
# 3  1.278  0.782     0.895
# 4  1.634  0.612     0.845

# %% [markdown]
# ![alt text](CHOP4.gif) ![alt text](CHOP4-1.png)

# %%
ch4=set([23,18,14,15,16,29,26,27,30,32,33,42,43,57,50,51,68,60,68,87,101,98,67])

#print(DFn[1][' '])
for k in list(ch4):
    #print(k)
    #print(DFn[0].loc[DFn[0][' '] == k].Area.values[0])
    Areas.append(DFn[4].loc[DFn[4][' '] == k].Area.values[0])

# %%
DFn[5].head()
# Out:
#       Label     Area     Min     Max       BX   BY   Width  Height  Circ.  \
# 0  1  CHOP6    5.342  11.000  12.333   10.897  0.0   5.128   1.282  0.561
# 1  2  CHOP6  100.674   9.333  12.333   23.077  0.0  12.179  10.897  0.556
# 2  3  CHOP6   89.579   7.000  12.333   53.205  0.0  10.897  10.897  0.695
# 3  4  CHOP6   96.154   7.000  12.333   85.256  0.0  16.026   8.333  0.658
# 4  5  CHOP6   14.382   8.667  12.333  107.051  0.0   5.128   4.487  0.755
#
#       AR  Round  Solidity
# 0  3.620  0.276     0.897
# 1  1.136  0.881     0.883
# 2  1.132  0.884     0.877
# 3  1.872  0.534     0.934
# 4  1.287  0.777     0.875

# %% [markdown]
# ![alt text](CHOP6.gif) ![alt text](CHOP6-1.png)

# %%
ch6=set([17,19,25,46,45,39,27,20,24,40,50,15,29,37,41,44,31,33,26,42])
#print(DFn[1][' '])
for k in list(ch6):
    #print(k)
    #print(DFn[0].loc[DFn[0][' '] == k].Area.values[0])
    Areas.append(DFn[5].loc[DFn[5][' '] == k].Area.values[0])

# %%
DFn[6].head()
# Out:
#      Label     Area     Min     Max      BX   BY   Width  Height  Circ.  \
# 0  1  ch12    3.369  10.067  11.413   0.000  0.0   1.231   3.694  0.566
# 1  2  ch12   46.149   8.395  11.517   5.335  0.0  15.185   5.335  0.439
# 2  3  ch12  187.626   9.024  11.526  11.081  0.0  26.265  15.185  0.421
# 3  4  ch12  159.330   8.398  11.519  40.219  0.0  15.595  13.133  0.875
# 4  5  ch12    8.421   9.821  11.515  57.456  0.0   6.156   1.642  0.587
#
#       AR  Round  Solidity
# 0  3.165  0.316     0.889
# 1  2.801  0.357     0.842
# 2  2.860  0.350     0.778
# 3  1.158  0.864     0.957
# 4  3.385  0.295     0.943

# %% [markdown]
# ![alt text](ch12.gif) ![alt text](ch12-1.png)

# %%
ch12=set([33,37,50,68,79,76,48,40,45,38,55,34,75,71,110,86,90,82,85,126,42])
#print(DFn[1][' '])
for k in list(ch12):
    #print(k)
    #print(DFn[0].loc[DFn[0][' '] == k].Area.values[0])
    Areas.append(DFn[6].loc[DFn[6][' '] == k].Area.values[0])

# %%
print(len(Areas))
# Out:
# 139

# %%
from scipy import stats

stats.describe(Areas)
# Out:
# DescribeResult(nobs=139, minmax=(62.458999999999996, 276.134), mean=160.0453381294964, variance=1874.726893457304, skewness=0.13227102957669934, kurtosis=-0.1460602033023135)

# %%
#!/usr/bin/env python
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import pylab

x = Areas

pylab.figure(figsize=(20,10))

# the histogram of the data
n, bins, patches = plt.hist(x, 50, normed=1, facecolor='green', alpha=0.75)

# add a 'best fit' line
y = mlab.normpdf( bins, 160.04, np.sqrt(1874.72))
l = plt.plot(bins, y, 'r--', linewidth=1.5)

plt.xlabel('Area $(\mu m)^2$')
plt.ylabel('Frequency')
plt.title(r'$Histogram$')
plt.axis([40, 350, 0, 0.03])
plt.grid(True)
